# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout,BatchNormalization ,Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras import regularizers

# %%
train_dir = '/kaggle/input/fer2013/train'
test_dir = '/kaggle/input/fer2013/test'

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=64,
    shuffle=True,
    subset='training'
)

val_generator = val_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=64,
    shuffle=True,
    subset='validation'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.

# %%
# Teszt adatok generálása
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir, 
    target_size=(48, 48),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=64,
    shuffle=True
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
input_size = (48, 48, 1)  # Grayscale images have only 1 channel
classes = 7 

#Initialising the CNN
model = tf.keras.models.Sequential()   

model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
    
model.add(Dense(classes, activation='softmax'))

    #Compliling the model
model.compile(optimizer=Adam(learning_rate=0.001), 
            loss='categorical_crossentropy', 
            metrics=['accuracy'])
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 22, 22, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 22, 22, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 11, 11, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 11, 11, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 30976)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    31,720,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         7,175 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,116,743 (122.52 MB)
#  Trainable params: 32,116,103 (122.51 MB)
#  Non-trainable params: 640 (2.50 KB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Define the callbacks
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

earlystop = EarlyStopping(
    monitor='val_loss', 
    min_delta=0, 
    patience=10, 
    verbose=1, 
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2, 
    patience=10, 
    verbose=1, 
    min_delta=0.0001
)


# Train the model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[checkpoint_callback, earlystop, reduce_lr]  # Add all callbacks here
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2176 - loss: 11.3991
# Epoch 1: val_accuracy improved from -inf to 0.18185, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 687s 2s/step - accuracy: 0.2176 - loss: 11.3862 - val_accuracy: 0.1818 - val_loss: 11.0116 - learning_rate: 0.0010
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2594 - loss: 2.1132
# Epoch 2: val_accuracy improved from 0.18185 to 0.31371, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 677s 2s/step - accuracy: 0.2594 - loss: 2.1130 - val_accuracy: 0.3137 - val_loss: 1.8056 - learning_rate: 0.0010
# Epoch 3/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2771 - loss: 1.8417
# Epoch 3: val_accuracy improved from 0.31371 to 0.32242, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 677s 2s/step - accuracy: 0.2771 - loss: 1.8416 - val_accuracy: 0.3224 - val_loss: 1.9455 - learning_rate: 0.0010
# Epoch 4/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3139 - loss: 1.7487
# Epoch 4: val_accuracy improved from 0.32242 to 0.38042, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 684s 2s/step - accuracy: 0.3139 - loss: 1.7487 - val_accuracy: 0.3804 - val_loss: 1.5988 - learning_rate: 0.0010
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3288 - loss: 1.7194
# Epoch 5: val_accuracy improved from 0.38042 to 0.39575, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 681s 2s/step - accuracy: 0.3288 - loss: 1.7193 - val_accuracy: 0.3957 - val_loss: 1.6067 - learning_rate: 0.0010
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3528 - loss: 1.6773
# Epoch 6: val_accuracy did not improve from 0.39575
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 686s 2s/step - accuracy: 0.3528 - loss: 1.6773 - val_accuracy: 0.3557 - val_loss: 1.6070 - learning_rate: 0.0010
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3728 - loss: 1.6318
# Epoch 7: val_accuracy improved from 0.39575 to 0.41230, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 687s 2s/step - accuracy: 0.3728 - loss: 1.6317 - val_accuracy: 0.4123 - val_loss: 1.5850 - learning_rate: 0.0010
# Epoch 8/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4019 - loss: 1.5855
# Epoch 8: val_accuracy improved from 0.41230 to 0.46299, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 684s 2s/step - accuracy: 0.4019 - loss: 1.5855 - val_accuracy: 0.4630 - val_loss: 1.4480 - learning_rate: 0.0010
# Epoch 9/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4096 - loss: 1.5579
# Epoch 9: val_accuracy improved from 0.46299 to 0.48737, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 685s 2s/step - accuracy: 0.4096 - loss: 1.5579 - val_accuracy: 0.4874 - val_loss: 1.3963 - learning_rate: 0.0010
# Epoch 10/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4185 - loss: 1.5335
# Epoch 10: val_accuracy did not improve from 0.48737
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 677s 2s/step - accuracy: 0.4186 - loss: 1.5335 - val_accuracy: 0.4708 - val_loss: 1.3915 - learning_rate: 0.0010
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4355 - loss: 1.5068
# Epoch 11: val_accuracy improved from 0.48737 to 0.49904, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 677s 2s/step - accuracy: 0.4355 - loss: 1.5068 - val_accuracy: 0.4990 - val_loss: 1.3615 - learning_rate: 0.0010
# Epoch 12/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4484 - loss: 1.4807
# Epoch 12: val_accuracy improved from 0.49904 to 0.50740, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 719s 2s/step - accuracy: 0.4484 - loss: 1.4807 - val_accuracy: 0.5074 - val_loss: 1.3267 - learning_rate: 0.0010
# Epoch 13/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4590 - loss: 1.4577
# Epoch 13: val_accuracy improved from 0.50740 to 0.51663, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 729s 2s/step - accuracy: 0.4590 - loss: 1.4577 - val_accuracy: 0.5166 - val_loss: 1.3100 - learning_rate: 0.0010
# Epoch 14/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4607 - loss: 1.4503
# Epoch 14: val_accuracy improved from 0.51663 to 0.52395, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 747s 2s/step - accuracy: 0.4607 - loss: 1.4503 - val_accuracy: 0.5240 - val_loss: 1.3036 - learning_rate: 0.0010
# Epoch 15/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4760 - loss: 1.4139
# Epoch 15: val_accuracy did not improve from 0.52395
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 717s 2s/step - accuracy: 0.4760 - loss: 1.4139 - val_accuracy: 0.4882 - val_loss: 1.4029 - learning_rate: 0.0010
# Epoch 16/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4735 - loss: 1.4218
# Epoch 16: val_accuracy improved from 0.52395 to 0.53231, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 727s 2s/step - accuracy: 0.4736 - loss: 1.4218 - val_accuracy: 0.5323 - val_loss: 1.2826 - learning_rate: 0.0010
# Epoch 17/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4877 - loss: 1.3831
# Epoch 17: val_accuracy improved from 0.53231 to 0.54921, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 722s 2s/step - accuracy: 0.4877 - loss: 1.3831 - val_accuracy: 0.5492 - val_loss: 1.2431 - learning_rate: 0.0010
# Epoch 18/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4924 - loss: 1.3748
# Epoch 18: val_accuracy did not improve from 0.54921
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 729s 2s/step - accuracy: 0.4924 - loss: 1.3748 - val_accuracy: 0.5429 - val_loss: 1.2477 - learning_rate: 0.0010
# Epoch 19/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5022 - loss: 1.3564
# Epoch 19: val_accuracy improved from 0.54921 to 0.55739, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.5022 - loss: 1.3564 - val_accuracy: 0.5574 - val_loss: 1.2198 - learning_rate: 0.0010
# Epoch 20/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5094 - loss: 1.3521
# Epoch 20: val_accuracy improved from 0.55739 to 0.57325, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 726s 2s/step - accuracy: 0.5094 - loss: 1.3521 - val_accuracy: 0.5732 - val_loss: 1.1745 - learning_rate: 0.0010
# Epoch 21/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5061 - loss: 1.3408
# Epoch 21: val_accuracy improved from 0.57325 to 0.58074, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 740s 2s/step - accuracy: 0.5061 - loss: 1.3408 - val_accuracy: 0.5807 - val_loss: 1.1705 - learning_rate: 0.0010
# Epoch 22/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5087 - loss: 1.3285
# Epoch 22: val_accuracy did not improve from 0.58074
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 742s 2s/step - accuracy: 0.5087 - loss: 1.3285 - val_accuracy: 0.5760 - val_loss: 1.1774 - learning_rate: 0.0010
# Epoch 23/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5174 - loss: 1.3158
# Epoch 23: val_accuracy did not improve from 0.58074
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 729s 2s/step - accuracy: 0.5174 - loss: 1.3159 - val_accuracy: 0.5583 - val_loss: 1.1962 - learning_rate: 0.0010
# Epoch 24/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5090 - loss: 1.3328
# Epoch 24: val_accuracy improved from 0.58074 to 0.58770, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 742s 2s/step - accuracy: 0.5090 - loss: 1.3328 - val_accuracy: 0.5877 - val_loss: 1.1411 - learning_rate: 0.0010
# Epoch 25/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5261 - loss: 1.3083
# Epoch 25: val_accuracy improved from 0.58770 to 0.59798, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 725s 2s/step - accuracy: 0.5260 - loss: 1.3083 - val_accuracy: 0.5980 - val_loss: 1.1355 - learning_rate: 0.0010
# Epoch 26/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5222 - loss: 1.3033
# Epoch 26: val_accuracy did not improve from 0.59798
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 726s 2s/step - accuracy: 0.5222 - loss: 1.3033 - val_accuracy: 0.5839 - val_loss: 1.1421 - learning_rate: 0.0010
# Epoch 27/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5368 - loss: 1.2673
# Epoch 27: val_accuracy did not improve from 0.59798
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 736s 2s/step - accuracy: 0.5368 - loss: 1.2674 - val_accuracy: 0.5799 - val_loss: 1.1607 - learning_rate: 0.0010
# Epoch 28/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5412 - loss: 1.2644
# Epoch 28: val_accuracy improved from 0.59798 to 0.59868, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 731s 2s/step - accuracy: 0.5412 - loss: 1.2644 - val_accuracy: 0.5987 - val_loss: 1.1259 - learning_rate: 0.0010
# Epoch 29/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5296 - loss: 1.2792
# Epoch 29: val_accuracy improved from 0.59868 to 0.60390, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 748s 2s/step - accuracy: 0.5296 - loss: 1.2792 - val_accuracy: 0.6039 - val_loss: 1.1034 - learning_rate: 0.0010
# Epoch 30/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5352 - loss: 1.2721
# Epoch 30: val_accuracy improved from 0.60390 to 0.61418, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 720s 2s/step - accuracy: 0.5352 - loss: 1.2721 - val_accuracy: 0.6142 - val_loss: 1.0871 - learning_rate: 0.0010
# Epoch 31/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5486 - loss: 1.2448
# Epoch 31: val_accuracy did not improve from 0.61418
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.5486 - loss: 1.2448 - val_accuracy: 0.6072 - val_loss: 1.1038 - learning_rate: 0.0010
# Epoch 32/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5499 - loss: 1.2460
# Epoch 32: val_accuracy did not improve from 0.61418
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 726s 2s/step - accuracy: 0.5499 - loss: 1.2460 - val_accuracy: 0.6072 - val_loss: 1.0919 - learning_rate: 0.0010
# Epoch 33/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5515 - loss: 1.2418
# Epoch 33: val_accuracy did not improve from 0.61418
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 731s 2s/step - accuracy: 0.5514 - loss: 1.2418 - val_accuracy: 0.6140 - val_loss: 1.0772 - learning_rate: 0.0010
# Epoch 34/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5463 - loss: 1.2408
# Epoch 34: val_accuracy improved from 0.61418 to 0.62028, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 733s 2s/step - accuracy: 0.5463 - loss: 1.2408 - val_accuracy: 0.6203 - val_loss: 1.0760 - learning_rate: 0.0010
# Epoch 35/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5519 - loss: 1.2368
# Epoch 35: val_accuracy did not improve from 0.62028
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 730s 2s/step - accuracy: 0.5519 - loss: 1.2368 - val_accuracy: 0.6145 - val_loss: 1.0488 - learning_rate: 0.0010
# Epoch 36/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5566 - loss: 1.2340
# Epoch 36: val_accuracy did not improve from 0.62028
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 751s 2s/step - accuracy: 0.5566 - loss: 1.2340 - val_accuracy: 0.6145 - val_loss: 1.0847 - learning_rate: 0.0010
# Epoch 37/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5579 - loss: 1.2269
# Epoch 37: val_accuracy improved from 0.62028 to 0.63351, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 780s 2s/step - accuracy: 0.5579 - loss: 1.2270 - val_accuracy: 0.6335 - val_loss: 1.0350 - learning_rate: 0.0010
# Epoch 38/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5684 - loss: 1.2057
# Epoch 38: val_accuracy improved from 0.63351 to 0.64153, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 725s 2s/step - accuracy: 0.5684 - loss: 1.2057 - val_accuracy: 0.6415 - val_loss: 1.0673 - learning_rate: 0.0010
# Epoch 39/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5619 - loss: 1.2269
# Epoch 39: val_accuracy did not improve from 0.64153
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 726s 2s/step - accuracy: 0.5619 - loss: 1.2269 - val_accuracy: 0.6243 - val_loss: 1.0517 - learning_rate: 0.0010
# Epoch 40/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5665 - loss: 1.1919
# Epoch 40: val_accuracy did not improve from 0.64153
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 720s 2s/step - accuracy: 0.5665 - loss: 1.1919 - val_accuracy: 0.6372 - val_loss: 1.0398 - learning_rate: 0.0010
# Epoch 41/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5667 - loss: 1.1927
# Epoch 41: val_accuracy did not improve from 0.64153
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 725s 2s/step - accuracy: 0.5667 - loss: 1.1927 - val_accuracy: 0.6403 - val_loss: 1.0088 - learning_rate: 0.0010
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5674 - loss: 1.2089
# Epoch 42: val_accuracy did not improve from 0.64153
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 742s 2s/step - accuracy: 0.5674 - loss: 1.2089 - val_accuracy: 0.6401 - val_loss: 1.0070 - learning_rate: 0.0010
# Epoch 43/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5728 - loss: 1.1936
# Epoch 43: val_accuracy improved from 0.64153 to 0.65877, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 749s 2s/step - accuracy: 0.5728 - loss: 1.1936 - val_accuracy: 0.6588 - val_loss: 0.9993 - learning_rate: 0.0010
# Epoch 44/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5773 - loss: 1.1865
# Epoch 44: val_accuracy did not improve from 0.65877
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 725s 2s/step - accuracy: 0.5773 - loss: 1.1865 - val_accuracy: 0.6373 - val_loss: 1.0190 - learning_rate: 0.0010
# Epoch 45/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5766 - loss: 1.1772
# Epoch 45: val_accuracy improved from 0.65877 to 0.66452, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 731s 2s/step - accuracy: 0.5766 - loss: 1.1772 - val_accuracy: 0.6645 - val_loss: 0.9858 - learning_rate: 0.0010
# Epoch 46/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5820 - loss: 1.1738
# Epoch 46: val_accuracy did not improve from 0.66452
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 737s 2s/step - accuracy: 0.5820 - loss: 1.1738 - val_accuracy: 0.6452 - val_loss: 1.0023 - learning_rate: 0.0010
# Epoch 47/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5814 - loss: 1.1775
# Epoch 47: val_accuracy did not improve from 0.66452
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 732s 2s/step - accuracy: 0.5814 - loss: 1.1775 - val_accuracy: 0.6468 - val_loss: 1.0201 - learning_rate: 0.0010
# Epoch 48/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5844 - loss: 1.1750
# Epoch 48: val_accuracy improved from 0.66452 to 0.67915, saving model to model_weights.weights.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 738s 2s/step - accuracy: 0.5844 - loss: 1.1750 - val_accuracy: 0.6791 - val_loss: 0.9319 - learning_rate: 0.0010
# Epoch 49/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5786 - loss: 1.1777
# Epoch 49: val_accuracy did not improve from 0.67915
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 729s 2s/step - accuracy: 0.5786 - loss: 1.1777 - val_accuracy: 0.6708 - val_loss: 0.9457 - learning_rate: 0.0010
# Epoch 50/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5876 - loss: 1.1543
# Epoch 50: val_accuracy did not improve from 0.67915
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 758s 2s/step - accuracy: 0.5876 - loss: 1.1543 - val_accuracy: 0.6657 - val_loss: 0.9517 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 48.

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
# Modell mentése
model.save('model_fer2013.h5')

# %%
# Modell kiértékelése a teszt adatokon
model.load_weights(filepath='/kaggle/working/model_weights.weights.h5')
evaluation = model.evaluate(test_generator, verbose=1)
print('Test Loss:', evaluation[0])
print('Test Accuracy:', evaluation[1])
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 49s 437ms/step - accuracy: 0.5945 - loss: 1.1480
# Test Loss: 1.1543115377426147
# Test Accuracy: 0.5998885631561279

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix
import numpy as np

# Get the true labels and predicted labels for the validation set
validation_labels = val_generator.classes
validation_pred_probs = model.predict(val_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 28s 307ms/step
